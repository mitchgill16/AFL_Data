# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder

# %%
df = pd.read_excel("Data/Fremantle_stats.xlsx")

# %%
df = df.T

# %%
df.columns = df.iloc[0]

# %%
df = df[1:]
df
# Out:
# Match_ID  Year Round H/A? H/A Win? Points For Points Against Margin  \
# 5150      2011     1    1        1         94             92      2
# 5159      2011     2    0        1         78             89    -11
# 5165      2011     3    1        1         79             54     25
# 5177      2011     4    0        0        127             98     29
# 5183      2011     5    0        0         85             78      7
# ...        ...   ...  ...      ...        ...            ...    ...
# 10485     2021    19    1        0         58             98    -40
# 10497     2021    20    0        0         55             51      4
# 10530     2021    21    0        1         54            118    -64
# 10515     2021    22    0        0         79             64     15
# 10521     2021    23    1        0         49            107    -58
#
# Match_ID Team Won? (1=W, 0=L) Team_against_ID Kicks  ...  \
# 5150                        1               2   184  ...
# ...

# %%
headers = []
to_remove = []
for x in range(0, len(df.columns)):
    #print(x)
    y = df.columns[x]
   # print(y[-1])
    headers.append(df.columns[x])
    if(y[-1] == '2'):
        print(y)
        to_remove.append(y)
    if(y[-2] == 'O'):
        if(y[-4] == '2'):
            print(y)
            to_remove.append(y)
# Out:
# Clangers2
# Clearances2
# Rebound 50s2
# Goals Assists2
# Clangers2(O)
# Clearances2(O)
# Rebound 50s2(O)
# Goals Assists2(O)
# ['Year',
#  'Round',
#  'H/A?',
#  'H/A Win?',
#  'Points For',
#  'Points Against',
#  'Margin',
#  'Team Won? (1=W, 0=L)',
#  'Team_against_ID',
#  'Kicks',
#  'Handballs',
#  'Disposals',
#  'Kick to HB Ratio',
#  'Marks',
#  'Tackles',
#  'Hitouts',
#  'Frees For',
#  'Frees Against',
#  'Goals Kicked',
#  'Goal Assists1',
#  'Behinds Kicked',
#  'Rushed Behinds',
#  'Scoring Shots',
#  'Conversion %',
#  'Disposals Per Goal',
#  'Disposals Per Scoring Shot',
#  'Clearances1',
#  'Clangers1',
#  'Rebound 50s1',
#  'Inside 50s',
#  'In50s Per Scoring Shot',
#  'In50s Per Goal',
#  '% In50s Score',
#  '% In50s Goal',
#  'Height',
#  'Weight',
#  'Age',
#  'Av Games',
#  '<50 Games',
#  '50-99 Games',
#  '100-149 Games',
#  '>150 Games',
#  'Contested Poss',
#  'Uncontested Poss',
#  'Effective Disposals',
#  'Disposal Efficiency',
#  'Clangers2',
# ...

# %%
len(df.columns)
# Out:
# 101
